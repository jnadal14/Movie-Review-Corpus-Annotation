# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
import json

# %%
# Configuration
webpage_url = f"https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/"
data_dir = "/Users/daomingliu/Desktop/mds-cl/523/COLX_523_Group-Repository_David-Daoming-Jacob-Nicole/data/retrieved_docs/"
last_doc_info_path = os.path.join(data_dir, f"last_doc_info.json")

# Mimic a request from a real web browser.
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %%
# Page number
if os.path.exists(last_doc_info_path):
    with open(last_doc_info_path, "r") as f:
        doc_info = json.load(f)  # Load JSON data
        page = doc_info.get("last_page", -1)  # Page number from last time
        last_review_position_on_page = doc_info.get("review_position_on_page", -1) # The position of the last fetched review on the page 
        file_num = doc_info.get("last_doc", -1)  # The file number
else:
    page = 1
    last_review_position_on_page = 1
    file_num = 0 

    
# Max number of reviews to retrieve
max_reviews = 1000 

# Number of file (or review) retrieved

# Ensure the data directory exists, create one if not
os.makedirs(data_dir, exist_ok=True)



# Loop until reaches the maximum number of reviews
while file_num <= max_reviews:
    url = f"{webpage_url}{page}/"
    print(f"Fetching page {page}: {url}")

    # Load page content
    response = requests.get(url, headers=headers)
    
    # checks whether the HTTP request was successful.
    if response.status_code != 200:
        print("No more pages or blocked by website. Stopping.")
        break
    
    # Locate the reviews from the page content
    soup = BeautifulSoup(response.text, "html.parser")
    reviews = soup.find_all("li", class_="film-detail")
    
    # If no reviews found, stop the loop
    if not reviews:
        print("No more reviews found. Stopping.")
        break

    current_position_on_page = 0
    for review in reviews:
        # Loop until reaches the maximum number of reviews
        if file_num > max_reviews:
            print("Reached maximum documents")
            break

        current_position_on_page += 1
        # If the current review on this page is already fetched from last time, continue
        if current_position_on_page <= last_review_position_on_page:
            continue

        
        try:
            # Extract reviewer username
            reviewer_tag = review.find("strong", class_="name")
            reviewer = reviewer_tag.get_text(strip=True) if reviewer_tag else "Unknown"

            # Extract reviewer's profile URL
            profile_tag = review.find("a", class_="avatar")
            profile_url = "https://letterboxd.com" + profile_tag["href"] if profile_tag else "No URL"

            # Extract review text
            review_text_tag = review.find("div", class_="body-text")
            review_text = review_text_tag.get_text(strip=True) if review_text_tag else "No review text"

            # Cap the word count for each comment to 60 words
            if len(review_text.split(" ")) > 60:
                continue

            file_num += 1
            file_path = os.path.join(data_dir, f"review_doc_{file_num}.txt")
            
            reviews_data = {
                "Reviewer": reviewer,
                "Profile_URL": profile_url,
                "Review": review_text
            }

            # Save the review as a document
            with open(file_path, 'w', encoding='utf-8') as f:
                json.dump(reviews_data, f)
                print(f"saved new document review_doc_{file_num}.txt")

            # Storing the current review-fetching progress
            doc_info = {
                "last_page": page,
                "review_position_on_page": current_position_on_page,
                "last_doc": file_num
            }
            with open(last_doc_info_path, "w") as f:
                json.dump(doc_info, f)

            
        # Skip if there's an issue with extracting data
        except AttributeError:
            continue  

    time.sleep(2)

    page += 1
    last_review_position_on_page = 0
# Out:
# Fetching page 41: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/41/
# Fetching page 42: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/42/
# saved new document review_doc_268.txt
# saved new document review_doc_269.txt
# saved new document review_doc_270.txt
# saved new document review_doc_271.txt
# saved new document review_doc_272.txt
# Fetching page 43: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/43/
# saved new document review_doc_273.txt
# saved new document review_doc_274.txt
# saved new document review_doc_275.txt
# saved new document review_doc_276.txt
# saved new document review_doc_277.txt
# saved new document review_doc_278.txt
# saved new document review_doc_279.txt
# saved new document review_doc_280.txt
# Fetching page 44: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/44/
# saved new document review_doc_281.txt
# saved new document review_doc_282.txt
# saved new document review_doc_283.txt
# Fetching page 45: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/45/
# saved new document review_doc_284.txt
# saved new document review_doc_285.txt
# saved new document review_doc_286.txt
# saved new document review_doc_287.txt
# saved new document review_doc_288.txt
# saved new document review_doc_289.txt
# saved new document review_doc_290.txt
# Fetching page 46: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/46/
# saved new document review_doc_291.txt
# saved new document review_doc_292.txt
# saved new document review_doc_293.txt
# saved new document review_doc_294.txt
# Fetching page 47: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/47/
# saved new document review_doc_295.txt
# saved new document review_doc_296.txt
# saved new document review_doc_297.txt
# saved new document review_doc_298.txt
# Fetching page 48: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/48/
# saved new document review_doc_299.txt
# saved new document review_doc_300.txt
# saved new document review_doc_301.txt
# saved new document review_doc_302.txt
# Fetching page 49: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/49/
# saved new document review_doc_303.txt
# saved new document review_doc_304.txt
# saved new document review_doc_305.txt
# Fetching page 50: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/50/
# saved new document review_doc_306.txt
# saved new document review_doc_307.txt
# saved new document review_doc_308.txt
# saved new document review_doc_309.txt
# saved new document review_doc_310.txt
# Fetching page 51: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/51/
# saved new document review_doc_311.txt
# saved new document review_doc_312.txt
# saved new document review_doc_313.txt
# saved new document review_doc_314.txt
# saved new document review_doc_315.txt
# saved new document review_doc_316.txt
# Fetching page 52: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/52/
# saved new document review_doc_317.txt
# saved new document review_doc_318.txt
# saved new document review_doc_319.txt
# saved new document review_doc_320.txt
# saved new document review_doc_321.txt
# Fetching page 53: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/53/
# saved new document review_doc_322.txt
# saved new document review_doc_323.txt
# saved new document review_doc_324.txt
# saved new document review_doc_325.txt
# saved new document review_doc_326.txt
# Fetching page 54: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/54/
# saved new document review_doc_327.txt
# saved new document review_doc_328.txt
# saved new document review_doc_329.txt
# saved new document review_doc_330.txt
# saved new document review_doc_331.txt
# saved new document review_doc_332.txt
# Fetching page 55: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/55/
# saved new document review_doc_333.txt
# saved new document review_doc_334.txt
# saved new document review_doc_335.txt
# saved new document review_doc_336.txt
# saved new document review_doc_337.txt
# saved new document review_doc_338.txt
# Fetching page 56: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/56/
# saved new document review_doc_339.txt
# saved new document review_doc_340.txt
# saved new document review_doc_341.txt
# saved new document review_doc_342.txt
# saved new document review_doc_343.txt
# saved new document review_doc_344.txt
# Fetching page 57: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/57/
# saved new document review_doc_345.txt
# saved new document review_doc_346.txt
# saved new document review_doc_347.txt
# saved new document review_doc_348.txt
# Fetching page 58: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/58/
# saved new document review_doc_349.txt
# saved new document review_doc_350.txt
# saved new document review_doc_351.txt
# saved new document review_doc_352.txt
# saved new document review_doc_353.txt
# Fetching page 59: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/59/
# saved new document review_doc_354.txt
# saved new document review_doc_355.txt
# saved new document review_doc_356.txt
# saved new document review_doc_357.txt
# Fetching page 60: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/60/
# saved new document review_doc_358.txt
# saved new document review_doc_359.txt
# saved new document review_doc_360.txt
# saved new document review_doc_361.txt
# saved new document review_doc_362.txt
# Fetching page 61: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/61/
# saved new document review_doc_363.txt
# saved new document review_doc_364.txt
# saved new document review_doc_365.txt
# saved new document review_doc_366.txt
# saved new document review_doc_367.txt
# saved new document review_doc_368.txt
# saved new document review_doc_369.txt
# saved new document review_doc_370.txt
# Fetching page 62: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/62/
# saved new document review_doc_371.txt
# saved new document review_doc_372.txt
# Fetching page 63: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/63/
# saved new document review_doc_373.txt
# saved new document review_doc_374.txt
# saved new document review_doc_375.txt
# saved new document review_doc_376.txt
# saved new document review_doc_377.txt
# saved new document review_doc_378.txt
# saved new document review_doc_379.txt
# Fetching page 64: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/64/
# saved new document review_doc_380.txt
# saved new document review_doc_381.txt
# saved new document review_doc_382.txt
# saved new document review_doc_383.txt
# saved new document review_doc_384.txt
# saved new document review_doc_385.txt
# Fetching page 65: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/65/
# saved new document review_doc_386.txt
# saved new document review_doc_387.txt
# saved new document review_doc_388.txt
# saved new document review_doc_389.txt
# saved new document review_doc_390.txt
# saved new document review_doc_391.txt
# Fetching page 66: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/66/
# saved new document review_doc_392.txt
# saved new document review_doc_393.txt
# saved new document review_doc_394.txt
# saved new document review_doc_395.txt
# saved new document review_doc_396.txt
# saved new document review_doc_397.txt
# saved new document review_doc_398.txt
# Fetching page 67: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/67/
# saved new document review_doc_399.txt
# saved new document review_doc_400.txt
# saved new document review_doc_401.txt
# saved new document review_doc_402.txt
# saved new document review_doc_403.txt
# Fetching page 68: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/68/
# saved new document review_doc_404.txt
# saved new document review_doc_405.txt
# saved new document review_doc_406.txt
# saved new document review_doc_407.txt
# saved new document review_doc_408.txt
# Fetching page 69: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/69/
# saved new document review_doc_409.txt
# saved new document review_doc_410.txt
# saved new document review_doc_411.txt
# saved new document review_doc_412.txt
# Fetching page 70: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/70/
# saved new document review_doc_413.txt
# saved new document review_doc_414.txt
# saved new document review_doc_415.txt
# saved new document review_doc_416.txt
# saved new document review_doc_417.txt
# saved new document review_doc_418.txt
# Fetching page 71: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/71/
# saved new document review_doc_419.txt
# saved new document review_doc_420.txt
# saved new document review_doc_421.txt
# saved new document review_doc_422.txt
# saved new document review_doc_423.txt
# Fetching page 72: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/72/
# saved new document review_doc_424.txt
# saved new document review_doc_425.txt
# saved new document review_doc_426.txt
# saved new document review_doc_427.txt
# saved new document review_doc_428.txt
# saved new document review_doc_429.txt
# Fetching page 73: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/73/
# saved new document review_doc_430.txt
# saved new document review_doc_431.txt
# saved new document review_doc_432.txt
# saved new document review_doc_433.txt
# saved new document review_doc_434.txt
# saved new document review_doc_435.txt
# saved new document review_doc_436.txt
# Fetching page 74: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/74/
# saved new document review_doc_437.txt
# saved new document review_doc_438.txt
# saved new document review_doc_439.txt
# saved new document review_doc_440.txt
# Fetching page 75: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/75/
# saved new document review_doc_441.txt
# saved new document review_doc_442.txt
# saved new document review_doc_443.txt
# saved new document review_doc_444.txt
# saved new document review_doc_445.txt
# saved new document review_doc_446.txt
# Fetching page 76: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/76/
# saved new document review_doc_447.txt
# saved new document review_doc_448.txt
# saved new document review_doc_449.txt
# saved new document review_doc_450.txt
# saved new document review_doc_451.txt
# Fetching page 77: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/77/
# saved new document review_doc_452.txt
# saved new document review_doc_453.txt
# saved new document review_doc_454.txt
# saved new document review_doc_455.txt
# saved new document review_doc_456.txt
# saved new document review_doc_457.txt
# Fetching page 78: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/78/
# saved new document review_doc_458.txt
# saved new document review_doc_459.txt
# Fetching page 79: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/79/
# saved new document review_doc_460.txt
# Fetching page 80: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/80/
# saved new document review_doc_461.txt
# saved new document review_doc_462.txt
# saved new document review_doc_463.txt
# saved new document review_doc_464.txt
# saved new document review_doc_465.txt
# saved new document review_doc_466.txt
# saved new document review_doc_467.txt
# saved new document review_doc_468.txt
# Fetching page 81: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/81/
# saved new document review_doc_469.txt
# saved new document review_doc_470.txt
# saved new document review_doc_471.txt
# saved new document review_doc_472.txt
# saved new document review_doc_473.txt
# Fetching page 82: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/82/
# saved new document review_doc_474.txt
# saved new document review_doc_475.txt
# saved new document review_doc_476.txt
# saved new document review_doc_477.txt
# saved new document review_doc_478.txt
# saved new document review_doc_479.txt
# Fetching page 83: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/83/
# saved new document review_doc_480.txt
# saved new document review_doc_481.txt
# saved new document review_doc_482.txt
# saved new document review_doc_483.txt
# saved new document review_doc_484.txt
# Fetching page 84: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/84/
# saved new document review_doc_485.txt
# saved new document review_doc_486.txt
# saved new document review_doc_487.txt
# saved new document review_doc_488.txt
# saved new document review_doc_489.txt
# saved new document review_doc_490.txt
# saved new document review_doc_491.txt
# saved new document review_doc_492.txt
# Fetching page 85: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/85/
# saved new document review_doc_493.txt
# saved new document review_doc_494.txt
# saved new document review_doc_495.txt
# saved new document review_doc_496.txt
# saved new document review_doc_497.txt
# Fetching page 86: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/86/
# saved new document review_doc_498.txt
# saved new document review_doc_499.txt
# saved new document review_doc_500.txt
# saved new document review_doc_501.txt
# saved new document review_doc_502.txt
# Fetching page 87: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/87/
# saved new document review_doc_503.txt
# saved new document review_doc_504.txt
# saved new document review_doc_505.txt
# saved new document review_doc_506.txt
# saved new document review_doc_507.txt
# saved new document review_doc_508.txt
# saved new document review_doc_509.txt
# Fetching page 88: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/88/
# saved new document review_doc_510.txt
# saved new document review_doc_511.txt
# saved new document review_doc_512.txt
# saved new document review_doc_513.txt
# saved new document review_doc_514.txt
# saved new document review_doc_515.txt
# Fetching page 89: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/89/
# saved new document review_doc_516.txt
# saved new document review_doc_517.txt
# saved new document review_doc_518.txt
# saved new document review_doc_519.txt
# Fetching page 90: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/90/
# saved new document review_doc_520.txt
# saved new document review_doc_521.txt
# saved new document review_doc_522.txt
# saved new document review_doc_523.txt
# saved new document review_doc_524.txt
# Fetching page 91: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/91/
# saved new document review_doc_525.txt
# saved new document review_doc_526.txt
# saved new document review_doc_527.txt
# saved new document review_doc_528.txt
# saved new document review_doc_529.txt
# saved new document review_doc_530.txt
# saved new document review_doc_531.txt
# Fetching page 92: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/92/
# saved new document review_doc_532.txt
# saved new document review_doc_533.txt
# saved new document review_doc_534.txt
# saved new document review_doc_535.txt
# saved new document review_doc_536.txt
# Fetching page 93: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/93/
# saved new document review_doc_537.txt
# saved new document review_doc_538.txt
# saved new document review_doc_539.txt
# Fetching page 94: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/94/
# saved new document review_doc_540.txt
# saved new document review_doc_541.txt
# saved new document review_doc_542.txt
# saved new document review_doc_543.txt
# Fetching page 95: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/95/
# saved new document review_doc_544.txt
# saved new document review_doc_545.txt
# saved new document review_doc_546.txt
# saved new document review_doc_547.txt
# saved new document review_doc_548.txt
# saved new document review_doc_549.txt
# saved new document review_doc_550.txt
# saved new document review_doc_551.txt
# saved new document review_doc_552.txt
# Fetching page 96: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/96/
# saved new document review_doc_553.txt
# saved new document review_doc_554.txt
# saved new document review_doc_555.txt
# saved new document review_doc_556.txt
# saved new document review_doc_557.txt
# Fetching page 97: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/97/
# saved new document review_doc_558.txt
# Fetching page 98: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/98/
# saved new document review_doc_559.txt
# saved new document review_doc_560.txt
# saved new document review_doc_561.txt
# saved new document review_doc_562.txt
# saved new document review_doc_563.txt
# saved new document review_doc_564.txt
# saved new document review_doc_565.txt
# Fetching page 99: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/99/
# saved new document review_doc_566.txt
# saved new document review_doc_567.txt
# saved new document review_doc_568.txt
# saved new document review_doc_569.txt
# saved new document review_doc_570.txt
# saved new document review_doc_571.txt
# Fetching page 100: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/100/
# saved new document review_doc_572.txt
# saved new document review_doc_573.txt
# saved new document review_doc_574.txt
# saved new document review_doc_575.txt
# Fetching page 101: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/101/
# saved new document review_doc_576.txt
# saved new document review_doc_577.txt
# saved new document review_doc_578.txt
# saved new document review_doc_579.txt
# Fetching page 102: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/102/
# saved new document review_doc_580.txt
# saved new document review_doc_581.txt
# saved new document review_doc_582.txt
# saved new document review_doc_583.txt
# saved new document review_doc_584.txt
# Fetching page 103: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/103/
# saved new document review_doc_585.txt
# saved new document review_doc_586.txt
# Fetching page 104: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/104/
# saved new document review_doc_587.txt
# saved new document review_doc_588.txt
# saved new document review_doc_589.txt
# saved new document review_doc_590.txt
# saved new document review_doc_591.txt
# saved new document review_doc_592.txt
# saved new document review_doc_593.txt
# Fetching page 105: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/105/
# saved new document review_doc_594.txt
# saved new document review_doc_595.txt
# saved new document review_doc_596.txt
# saved new document review_doc_597.txt
# saved new document review_doc_598.txt
# saved new document review_doc_599.txt
# Fetching page 106: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/106/
# saved new document review_doc_600.txt
# saved new document review_doc_601.txt
# saved new document review_doc_602.txt
# saved new document review_doc_603.txt
# saved new document review_doc_604.txt
# saved new document review_doc_605.txt
# Fetching page 107: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/107/
# saved new document review_doc_606.txt
# saved new document review_doc_607.txt
# saved new document review_doc_608.txt
# saved new document review_doc_609.txt
# saved new document review_doc_610.txt
# saved new document review_doc_611.txt
# saved new document review_doc_612.txt
# saved new document review_doc_613.txt
# Fetching page 108: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/108/
# saved new document review_doc_614.txt
# saved new document review_doc_615.txt
# saved new document review_doc_616.txt
# saved new document review_doc_617.txt
# saved new document review_doc_618.txt
# saved new document review_doc_619.txt
# Fetching page 109: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/109/
# saved new document review_doc_620.txt
# saved new document review_doc_621.txt
# saved new document review_doc_622.txt
# saved new document review_doc_623.txt
# saved new document review_doc_624.txt
# saved new document review_doc_625.txt
# saved new document review_doc_626.txt
# Fetching page 110: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/110/
# saved new document review_doc_627.txt
# saved new document review_doc_628.txt
# saved new document review_doc_629.txt
# saved new document review_doc_630.txt
# saved new document review_doc_631.txt
# Fetching page 111: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/111/
# saved new document review_doc_632.txt
# saved new document review_doc_633.txt
# saved new document review_doc_634.txt
# saved new document review_doc_635.txt
# saved new document review_doc_636.txt
# Fetching page 112: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/112/
# saved new document review_doc_637.txt
# saved new document review_doc_638.txt
# saved new document review_doc_639.txt
# saved new document review_doc_640.txt
# saved new document review_doc_641.txt
# saved new document review_doc_642.txt
# Fetching page 113: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/113/
# saved new document review_doc_643.txt
# saved new document review_doc_644.txt
# saved new document review_doc_645.txt
# saved new document review_doc_646.txt
# Fetching page 114: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/114/
# saved new document review_doc_647.txt
# saved new document review_doc_648.txt
# saved new document review_doc_649.txt
# saved new document review_doc_650.txt
# saved new document review_doc_651.txt
# saved new document review_doc_652.txt
# Fetching page 115: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/115/
# saved new document review_doc_653.txt
# saved new document review_doc_654.txt
# saved new document review_doc_655.txt
# saved new document review_doc_656.txt
# Fetching page 116: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/116/
# saved new document review_doc_657.txt
# saved new document review_doc_658.txt
# Fetching page 117: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/117/
# saved new document review_doc_659.txt
# saved new document review_doc_660.txt
# saved new document review_doc_661.txt
# saved new document review_doc_662.txt
# saved new document review_doc_663.txt
# saved new document review_doc_664.txt
# saved new document review_doc_665.txt
# Fetching page 118: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/118/
# saved new document review_doc_666.txt
# saved new document review_doc_667.txt
# saved new document review_doc_668.txt
# saved new document review_doc_669.txt
# saved new document review_doc_670.txt
# saved new document review_doc_671.txt
# saved new document review_doc_672.txt
# Fetching page 119: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/119/
# saved new document review_doc_673.txt
# saved new document review_doc_674.txt
# saved new document review_doc_675.txt
# saved new document review_doc_676.txt
# saved new document review_doc_677.txt
# saved new document review_doc_678.txt
# Fetching page 120: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/120/
# saved new document review_doc_679.txt
# saved new document review_doc_680.txt
# saved new document review_doc_681.txt
# saved new document review_doc_682.txt
# saved new document review_doc_683.txt
# saved new document review_doc_684.txt
# saved new document review_doc_685.txt
# Fetching page 121: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/121/
# saved new document review_doc_686.txt
# saved new document review_doc_687.txt
# saved new document review_doc_688.txt
# saved new document review_doc_689.txt
# Fetching page 122: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/122/
# saved new document review_doc_690.txt
# saved new document review_doc_691.txt
# saved new document review_doc_692.txt
# saved new document review_doc_693.txt
# saved new document review_doc_694.txt
# saved new document review_doc_695.txt
# saved new document review_doc_696.txt
# Fetching page 123: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/123/
# saved new document review_doc_697.txt
# saved new document review_doc_698.txt
# saved new document review_doc_699.txt
# saved new document review_doc_700.txt
# saved new document review_doc_701.txt
# saved new document review_doc_702.txt
# saved new document review_doc_703.txt
# Fetching page 124: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/124/
# saved new document review_doc_704.txt
# saved new document review_doc_705.txt
# saved new document review_doc_706.txt
# saved new document review_doc_707.txt
# saved new document review_doc_708.txt
# saved new document review_doc_709.txt
# saved new document review_doc_710.txt
# Fetching page 125: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/125/
# saved new document review_doc_711.txt
# saved new document review_doc_712.txt
# saved new document review_doc_713.txt
# saved new document review_doc_714.txt
# Fetching page 126: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/126/
# saved new document review_doc_715.txt
# saved new document review_doc_716.txt
# saved new document review_doc_717.txt
# saved new document review_doc_718.txt
# saved new document review_doc_719.txt
# saved new document review_doc_720.txt
# saved new document review_doc_721.txt
# saved new document review_doc_722.txt
# Fetching page 127: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/127/
# saved new document review_doc_723.txt
# saved new document review_doc_724.txt
# saved new document review_doc_725.txt
# Fetching page 128: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/128/
# saved new document review_doc_726.txt
# saved new document review_doc_727.txt
# saved new document review_doc_728.txt
# saved new document review_doc_729.txt
# saved new document review_doc_730.txt
# saved new document review_doc_731.txt
# Fetching page 129: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/129/
# saved new document review_doc_732.txt
# saved new document review_doc_733.txt
# saved new document review_doc_734.txt
# saved new document review_doc_735.txt
# Fetching page 130: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/130/
# saved new document review_doc_736.txt
# saved new document review_doc_737.txt
# saved new document review_doc_738.txt
# saved new document review_doc_739.txt
# Fetching page 131: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/131/
# saved new document review_doc_740.txt
# saved new document review_doc_741.txt
# saved new document review_doc_742.txt
# saved new document review_doc_743.txt
# Fetching page 132: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/132/
# saved new document review_doc_744.txt
# saved new document review_doc_745.txt
# Fetching page 133: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/133/
# saved new document review_doc_746.txt
# saved new document review_doc_747.txt
# saved new document review_doc_748.txt
# saved new document review_doc_749.txt
# saved new document review_doc_750.txt
# saved new document review_doc_751.txt
# Fetching page 134: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/134/
# saved new document review_doc_752.txt
# saved new document review_doc_753.txt
# saved new document review_doc_754.txt
# saved new document review_doc_755.txt
# saved new document review_doc_756.txt
# Fetching page 135: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/135/
# saved new document review_doc_757.txt
# saved new document review_doc_758.txt
# saved new document review_doc_759.txt
# saved new document review_doc_760.txt
# saved new document review_doc_761.txt
# Fetching page 136: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/136/
# saved new document review_doc_762.txt
# saved new document review_doc_763.txt
# saved new document review_doc_764.txt
# saved new document review_doc_765.txt
# saved new document review_doc_766.txt
# saved new document review_doc_767.txt
# saved new document review_doc_768.txt
# Fetching page 137: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/137/
# saved new document review_doc_769.txt
# saved new document review_doc_770.txt
# saved new document review_doc_771.txt
# saved new document review_doc_772.txt
# Fetching page 138: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/138/
# saved new document review_doc_773.txt
# saved new document review_doc_774.txt
# saved new document review_doc_775.txt
# saved new document review_doc_776.txt
# saved new document review_doc_777.txt
# saved new document review_doc_778.txt
# saved new document review_doc_779.txt
# Fetching page 139: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/139/
# saved new document review_doc_780.txt
# saved new document review_doc_781.txt
# saved new document review_doc_782.txt
# saved new document review_doc_783.txt
# saved new document review_doc_784.txt
# Fetching page 140: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/140/
# saved new document review_doc_785.txt
# saved new document review_doc_786.txt
# saved new document review_doc_787.txt
# saved new document review_doc_788.txt
# saved new document review_doc_789.txt
# saved new document review_doc_790.txt
# saved new document review_doc_791.txt
# Fetching page 141: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/141/
# saved new document review_doc_792.txt
# saved new document review_doc_793.txt
# saved new document review_doc_794.txt
# saved new document review_doc_795.txt
# saved new document review_doc_796.txt
# saved new document review_doc_797.txt
# saved new document review_doc_798.txt
# Fetching page 142: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/142/
# saved new document review_doc_799.txt
# saved new document review_doc_800.txt
# saved new document review_doc_801.txt
# saved new document review_doc_802.txt
# saved new document review_doc_803.txt
# saved new document review_doc_804.txt
# saved new document review_doc_805.txt
# Fetching page 143: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/143/
# saved new document review_doc_806.txt
# saved new document review_doc_807.txt
# saved new document review_doc_808.txt
# saved new document review_doc_809.txt
# Fetching page 144: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/144/
# saved new document review_doc_810.txt
# saved new document review_doc_811.txt
# saved new document review_doc_812.txt
# saved new document review_doc_813.txt
# saved new document review_doc_814.txt
# saved new document review_doc_815.txt
# Fetching page 145: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/145/
# saved new document review_doc_816.txt
# saved new document review_doc_817.txt
# saved new document review_doc_818.txt
# saved new document review_doc_819.txt
# saved new document review_doc_820.txt
# saved new document review_doc_821.txt
# Fetching page 146: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/146/
# saved new document review_doc_822.txt
# saved new document review_doc_823.txt
# saved new document review_doc_824.txt
# saved new document review_doc_825.txt
# saved new document review_doc_826.txt
# Fetching page 147: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/147/
# saved new document review_doc_827.txt
# saved new document review_doc_828.txt
# saved new document review_doc_829.txt
# saved new document review_doc_830.txt
# Fetching page 148: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/148/
# saved new document review_doc_831.txt
# saved new document review_doc_832.txt
# saved new document review_doc_833.txt
# saved new document review_doc_834.txt
# saved new document review_doc_835.txt
# Fetching page 149: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/149/
# saved new document review_doc_836.txt
# saved new document review_doc_837.txt
# saved new document review_doc_838.txt
# saved new document review_doc_839.txt
# Fetching page 150: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/150/
# saved new document review_doc_840.txt
# saved new document review_doc_841.txt
# saved new document review_doc_842.txt
# saved new document review_doc_843.txt
# saved new document review_doc_844.txt
# Fetching page 151: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/151/
# saved new document review_doc_845.txt
# saved new document review_doc_846.txt
# saved new document review_doc_847.txt
# saved new document review_doc_848.txt
# saved new document review_doc_849.txt
# saved new document review_doc_850.txt
# saved new document review_doc_851.txt
# saved new document review_doc_852.txt
# saved new document review_doc_853.txt
# saved new document review_doc_854.txt
# Fetching page 152: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/152/
# saved new document review_doc_855.txt
# saved new document review_doc_856.txt
# saved new document review_doc_857.txt
# saved new document review_doc_858.txt
# saved new document review_doc_859.txt
# saved new document review_doc_860.txt
# Fetching page 153: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/153/
# saved new document review_doc_861.txt
# saved new document review_doc_862.txt
# saved new document review_doc_863.txt
# saved new document review_doc_864.txt
# saved new document review_doc_865.txt
# saved new document review_doc_866.txt
# Fetching page 154: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/154/
# saved new document review_doc_867.txt
# saved new document review_doc_868.txt
# saved new document review_doc_869.txt
# Fetching page 155: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/155/
# saved new document review_doc_870.txt
# saved new document review_doc_871.txt
# saved new document review_doc_872.txt
# saved new document review_doc_873.txt
# Fetching page 156: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/156/
# saved new document review_doc_874.txt
# saved new document review_doc_875.txt
# Fetching page 157: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/157/
# saved new document review_doc_876.txt
# saved new document review_doc_877.txt
# saved new document review_doc_878.txt
# saved new document review_doc_879.txt
# saved new document review_doc_880.txt
# Fetching page 158: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/158/
# saved new document review_doc_881.txt
# saved new document review_doc_882.txt
# saved new document review_doc_883.txt
# Fetching page 159: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/159/
# saved new document review_doc_884.txt
# saved new document review_doc_885.txt
# saved new document review_doc_886.txt
# saved new document review_doc_887.txt
# saved new document review_doc_888.txt
# Fetching page 160: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/160/
# saved new document review_doc_889.txt
# saved new document review_doc_890.txt
# saved new document review_doc_891.txt
# saved new document review_doc_892.txt
# saved new document review_doc_893.txt
# Fetching page 161: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/161/
# saved new document review_doc_894.txt
# saved new document review_doc_895.txt
# saved new document review_doc_896.txt
# saved new document review_doc_897.txt
# saved new document review_doc_898.txt
# saved new document review_doc_899.txt
# Fetching page 162: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/162/
# saved new document review_doc_900.txt
# saved new document review_doc_901.txt
# saved new document review_doc_902.txt
# saved new document review_doc_903.txt
# saved new document review_doc_904.txt
# saved new document review_doc_905.txt
# saved new document review_doc_906.txt
# Fetching page 163: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/163/
# saved new document review_doc_907.txt
# saved new document review_doc_908.txt
# saved new document review_doc_909.txt
# saved new document review_doc_910.txt
# saved new document review_doc_911.txt
# Fetching page 164: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/164/
# saved new document review_doc_912.txt
# saved new document review_doc_913.txt
# saved new document review_doc_914.txt
# saved new document review_doc_915.txt
# Fetching page 165: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/165/
# saved new document review_doc_916.txt
# saved new document review_doc_917.txt
# saved new document review_doc_918.txt
# saved new document review_doc_919.txt
# Fetching page 166: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/166/
# saved new document review_doc_920.txt
# saved new document review_doc_921.txt
# saved new document review_doc_922.txt
# saved new document review_doc_923.txt
# Fetching page 167: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/167/
# saved new document review_doc_924.txt
# saved new document review_doc_925.txt
# saved new document review_doc_926.txt
# Fetching page 168: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/168/
# saved new document review_doc_927.txt
# saved new document review_doc_928.txt
# saved new document review_doc_929.txt
# saved new document review_doc_930.txt
# saved new document review_doc_931.txt
# Fetching page 169: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/169/
# saved new document review_doc_932.txt
# saved new document review_doc_933.txt
# saved new document review_doc_934.txt
# saved new document review_doc_935.txt
# Fetching page 170: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/170/
# saved new document review_doc_936.txt
# saved new document review_doc_937.txt
# saved new document review_doc_938.txt
# saved new document review_doc_939.txt
# saved new document review_doc_940.txt
# Fetching page 171: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/171/
# saved new document review_doc_941.txt
# saved new document review_doc_942.txt
# saved new document review_doc_943.txt
# saved new document review_doc_944.txt
# saved new document review_doc_945.txt
# saved new document review_doc_946.txt
# saved new document review_doc_947.txt
# Fetching page 172: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/172/
# saved new document review_doc_948.txt
# saved new document review_doc_949.txt
# saved new document review_doc_950.txt
# saved new document review_doc_951.txt
# saved new document review_doc_952.txt
# saved new document review_doc_953.txt
# Fetching page 173: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/173/
# saved new document review_doc_954.txt
# saved new document review_doc_955.txt
# saved new document review_doc_956.txt
# saved new document review_doc_957.txt
# saved new document review_doc_958.txt
# saved new document review_doc_959.txt
# Fetching page 174: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/174/
# saved new document review_doc_960.txt
# saved new document review_doc_961.txt
# saved new document review_doc_962.txt
# saved new document review_doc_963.txt
# saved new document review_doc_964.txt
# saved new document review_doc_965.txt
# Fetching page 175: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/175/
# saved new document review_doc_966.txt
# saved new document review_doc_967.txt
# saved new document review_doc_968.txt
# saved new document review_doc_969.txt
# saved new document review_doc_970.txt
# saved new document review_doc_971.txt
# Fetching page 176: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/176/
# saved new document review_doc_972.txt
# saved new document review_doc_973.txt
# saved new document review_doc_974.txt
# saved new document review_doc_975.txt
# saved new document review_doc_976.txt
# Fetching page 177: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/177/
# saved new document review_doc_977.txt
# saved new document review_doc_978.txt
# saved new document review_doc_979.txt
# Fetching page 178: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/178/
# saved new document review_doc_980.txt
# saved new document review_doc_981.txt
# saved new document review_doc_982.txt
# saved new document review_doc_983.txt
# saved new document review_doc_984.txt
# saved new document review_doc_985.txt
# Fetching page 179: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/179/
# saved new document review_doc_986.txt
# saved new document review_doc_987.txt
# saved new document review_doc_988.txt
# saved new document review_doc_989.txt
# Fetching page 180: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/180/
# saved new document review_doc_990.txt
# saved new document review_doc_991.txt
# saved new document review_doc_992.txt
# saved new document review_doc_993.txt
# saved new document review_doc_994.txt
# Fetching page 181: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/181/
# saved new document review_doc_995.txt
# saved new document review_doc_996.txt
# saved new document review_doc_997.txt
# saved new document review_doc_998.txt
# saved new document review_doc_999.txt
# saved new document review_doc_1000.txt
# saved new document review_doc_1001.txt
# Reached maximum documents

# %%
reviews_data = {}
page = 1
max_reviews = 1000 
file_num = 0
while file_num < max_reviews:
    url = f"{base_url}{page}/"
    print(f"Fetching page {page}: {url}")

    # Load page content
    response = requests.get(url, headers=headers)
    
    # checks whether the HTTP request was successful.
    if response.status_code != 200:
        print("No more pages or blocked by website. Stopping.")
        break
    
    # Locate the reviews from the page content
    soup = BeautifulSoup(response.text, "html.parser")
    reviews = soup.find_all("li", class_="film-detail")
    
    # If no reviews found, stop the loop
    if not reviews:
        print("No more reviews found. Stopping.")
        break

    for review in reviews:
        if file_num > max_reviews:
            print("Reached maximum documents")
            break
    
        try:
            # Extract reviewer username
            reviewer_tag = review.find("strong", class_="name")
            reviewer = reviewer_tag.get_text(strip=True) if reviewer_tag else "Unknown"

            # Extract reviewer's profile URL
            profile_tag = review.find("a", class_="avatar")
            profile_url = "https://letterboxd.com" + profile_tag["href"] if profile_tag else "No URL"

            # Extract review text
            review_text_tag = review.find("div", class_="body-text")
            review_text = review_text_tag.get_text(strip=True) if review_text_tag else "No review text"

            if len(review_text.split(" ")) > 20:
                continue

            reviews_data = {
                "Reviewer": reviewer,
                "Profile_URL": profile_url,
                "Movie": movie_slug.title(),
                "Review": review_text
            }

            file_num += 1
            file_path = os.path.join(data_dir, f"review_doc_{file_num}.txt")

            if os.path.exists(file_path):
                continue
        
            with open(file_path, 'w', encoding='utf-8') as f:
                json.dump({
                    "Reviewer": reviewer,
                    "Profile_URL": profile_url,
                    "Movie": movie_slug.title(),
                    "Review": review_text
                }, f)  

            print(f"Saved doc_{file_num}")

        # Skip if there's an issue with extracting data
        except AttributeError:
            continue  

    time.sleep(2)
    
    page += 1
# Out:
# Fetching page 1: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/1/
# Fetching page 2: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/2/
# Fetching page 3: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/3/
# Fetching page 4: https://letterboxd.com/film/oppenheimer-2023/reviews/by/activity/page/4/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 75
#      72     except AttributeError:
#      73         continue
# ---> 75 time.sleep(2)
#      77 page += 1
#
# KeyboardInterrupt:
